# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.__version__
# Out:
# '1.4.0'

# %%
#conda install --upgrade pandas

# %%
#conda update pandas

# %%
# import dataset
df = pd.read_csv('data/movies.csv')
df.head()
# Out:
#    Rank                         Title       Studio       Gross  Year
# 0     1             Avengers: Endgame  Buena Vista  $2,796.30   2019
# 1     2                        Avatar          Fox  $2,789.70   2009
# 2     3                       Titanic    Paramount  $2,187.50   1997
# 3     4  Star Wars: The Force Awakens  Buena Vista  $2,068.20   2015
# 4     5        Avengers: Infinity War  Buena Vista  $2,048.40   2018

# %%
df.shape
# Out:
# (782, 5)

# %%
df.size
# Out:
# 3910

# %%
# datatype of each column
df.dtypes
# Out:
# Rank       int64
# Title     object
# Studio    object
# Gross     object
# Year       int64
# dtype: object

# %%
# indexing to get any 1 record
df.iloc[22]
# Out:
# Rank                                  23
# Title     Transformers: Dark of the Moon
# Studio                         Paramount
# Gross                         $1,123.80
# Year                                2011
# Name: 22, dtype: object

# %%
df.loc[22]
# Out:
# Rank                                  23
# Title     Transformers: Dark of the Moon
# Studio                         Paramount
# Gross                         $1,123.80
# Year                                2011
# Name: 22, dtype: object

# %%
df.loc[:22]
# Out:
#     Rank                                        Title           Studio  \
# 0      1                            Avengers: Endgame      Buena Vista
# 1      2                                       Avatar              Fox
# 2      3                                      Titanic        Paramount
# 3      4                 Star Wars: The Force Awakens      Buena Vista
# 4      5                       Avengers: Infinity War      Buena Vista
# 5      6                               Jurassic World        Universal
# 6      7                        Marvel's The Avengers      Buena Vista
# 7      8                                    Furious 7        Universal
# 8      9                      Avengers: Age of Ultron      Buena Vista
# 9     10                                Black Panther      Buena Vista
# 10    11  Harry Potter and the Deathly Hallows Part 2  Warner Brothers
# 11    12                     Star Wars: The Last Jedi      Buena Vista
# ...

# %%
# extract with a label than number
#df.loc["Dark Knight"]

# %%
#df.iloc["Frozen"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-5a8bba66bd9c> in <module>
# ----> 1 df.iloc["Frozen"]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     965
#     966             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967             return self._getitem_axis(maybe_callable, axis=axis)
#     968
#     969     def _is_scalar_access(self, key: tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1515             key = item_from_zerodim(key)
#    1516             if not is_integer(key):
# -> 1517                 raise TypeError("Cannot index by location index with a non-integer key")
#    1518
#    1519             # validate the location
#
# TypeError: Cannot index by location index with a non-integer key

# %%
#df.loc['Frozen']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-d9f05e0846b7> in <module>
# ----> 1 df.loc['Frozen']
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     965
#     966             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967             return self._getitem_axis(maybe_callable, axis=axis)
#     968
#     969     def _is_scalar_access(self, key: tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1200         # fall thru to straight lookup
#    1201         self._validate_key(key, axis)
# -> 1202         return self._get_label(key, axis=axis)
#    1203
#    1204     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
# ...

# %%
#df.loc["Star Wars: The Last Jedi"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-752a0ae26b6e> in <module>
# ----> 1 df.loc["Star Wars: The Last Jedi"]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     965
#     966             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967             return self._getitem_axis(maybe_callable, axis=axis)
#     968
#     969     def _is_scalar_access(self, key: tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1200         # fall thru to straight lookup
#    1201         self._validate_key(key, axis)
# -> 1202         return self._get_label(key, axis=axis)
#    1203
#    1204     def _get_slice_axis(self, slice_obj: slice, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
# ...

# %%
df.sort_values(by = "Year" , ascending = False).head()
# Out:
#      Rank                                       Title                  Studio  \
# 0       1                           Avengers: Endgame             Buena Vista
# 457   458           John Wick: Chapter 3 - Parabellum               Lionsgate
# 113   114                         The Wandering Earth  China Film Corporation
# 197   198                                 Toy Story 4             Buena Vista
# 198   199  How to Train Your Dragon: The Hidden World               Universal
#
#           Gross  Year
# 0    $2,796.30   2019
# 457    $304.70   2019
# 113    $699.80   2019
# 197    $519.80   2019
# 198    $519.80   2019

# %%
df.sort_values(by = "Year" , ascending = True).head()
# Out:
#      Rank               Title       Studio     Gross  Year
# 287   288  Gone with the Wind          MGM  $402.40   1939
# 539   540               Bambi          RKO  $267.40   1942
# 707   708      101 Dalmatians  Buena Vista  $215.90   1961
# 754   755     The Jungle Book  Buena Vista  $205.80   1967
# 603   604       The Godfather    Paramount  $245.10   1972

# %%
# sort by using 2 columns
df.sort_values(by = ["Gross", "Year"]).head(10)
# Out:
#     Rank                                        Title           Studio  \
# 38    39                              The Dark Knight  Warner Brothers
# 37    38            The Hobbit: An Unexpected Journey  Warner Brothers
# 36    37                                     Zootopia      Buena Vista
# 35    36                          Alice in Wonderland      Buena Vista
# 34    35    Star Wars: Episode I - The Phantom Menace              Fox
# 33    34                                 Finding Dory      Buena Vista
# 32    33                                Jurassic Park        Universal
# 31    32                              Despicable Me 3        Universal
# 30    31  Pirates of the Caribbean: On Stranger Tides      Buena Vista
# 29    30                 Rogue One: A Star Wars Story      Buena Vista
#
#          Gross  Year
# 38  $1,004.90   2008
# 37  $1,021.10   2012
# 36  $1,023.80   2016
# 35  $1,025.50   2010
# 34  $1,027.00   1999
# 33  $1,028.60   2016
# 32  $1,029.50   1993
# ...

# %%
df.sort_values(by = ["Studio", "Year"]).head(10)
# Out:
#      Rank                     Title       Studio     Gross  Year
# 587   588   The Blair Witch Project      Artisan  $248.60   1999
# 707   708            101 Dalmatians  Buena Vista  $215.90   1961
# 754   755           The Jungle Book  Buena Vista  $205.80   1967
# 409   410   Who Framed Roger Rabbit  Buena Vista  $329.80   1988
# 635   636        Dead Poets Society  Buena Vista  $235.90   1989
# 678   679  Honey, I Shrunk the Kids  Buena Vista  $222.70   1989
# 737   738        The Little Mermaid  Buena Vista  $211.30   1989
# 233   234              Pretty Woman  Buena Vista  $463.40   1990
# 266   267      Beauty and the Beast  Buena Vista  $425.00   1991
# 203   204                   Aladdin  Buena Vista  $504.10   1992

# %%
# sort with alphabetical order
# it will sort based on Rank which is default indexing of the dataset!

df.sort_index().head()
# Out:
#    Rank                         Title       Studio       Gross  Year
# 0     1             Avengers: Endgame  Buena Vista  $2,796.30   2019
# 1     2                        Avatar          Fox  $2,789.70   2009
# 2     3                       Titanic    Paramount  $2,187.50   1997
# 3     4  Star Wars: The Force Awakens  Buena Vista  $2,068.20   2015
# 4     5        Avengers: Infinity War  Buena Vista  $2,048.40   2018

# %%
df.dtypes
# Out:
# Rank       int64
# Title     object
# Studio    object
# Gross     object
# Year       int64
# dtype: object

# %%
# find out which movie studio had the greatest number of highest-grossing films
df['Studio'].value_counts()
# Out:
# Warner Brothers           132
# Buena Vista               125
# Fox                       117
# Universal                 109
# Sony                       86
# Paramount                  76
# Dreamworks                 27
# Lionsgate                  21
# New Line                   16
# MGM                        11
# TriStar                    11
# Miramax                    10
# Weinstein                   6
# Columbia                    5
# WGUSA                       4
# Polygram                    2
# Orion                       2
# SonR                        2
# Dimension                   2
# Vestron                     1
# USA                         1
# Lions                       1
# Focus                       1
# Rela.                       1
# CL                          1
# Pathe                       1
# Artisan                     1
# IFC                         1
# GrtIndia                    1
# RKO                         1
# UTV                         1
# ...

# %%
# Filtering a column by one or more criteria

# films by only one studio

df[df["Studio"]=='Buena Vista']
# Out:
#      Rank                         Title       Studio       Gross  Year
# 0       1             Avengers: Endgame  Buena Vista  $2,796.30   2019
# 3       4  Star Wars: The Force Awakens  Buena Vista  $2,068.20   2015
# 4       5        Avengers: Infinity War  Buena Vista  $2,048.40   2018
# 6       7         Marvel's The Avengers  Buena Vista  $1,518.80   2012
# 8       9       Avengers: Age of Ultron  Buena Vista  $1,405.40   2015
# ..    ...                           ...          ...         ...   ...
# 744   745                  Tomorrowland  Buena Vista    $209.20   2015
# 754   755               The Jungle Book  Buena Vista    $205.80   1967
# 764   765                   King Arthur  Buena Vista    $203.60   2004
# 768   769                Need for Speed  Buena Vista    $203.30   2014
# 770   771                         Ponyo  Buena Vista    $202.40   2009
#
# [125 rows x 5 columns]

# %%
# assigning it a variable for further operations

released_by_studio = ([df["Studio"]=='Buena Vista'])

# %%
released_by_studio
# Out:
# [0       True
#  1      False
#  2      False
#  3       True
#  4       True
#         ...
#  777    False
#  778    False
#  779    False
#  780    False
#  781    False
#  Name: Studio, Length: 782, dtype: bool]

# %%
released_in_2015 = (df["Year"] == 2015) 
released_in_2015
# df[released_by_studio & released_in_2015]
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 777    False
# 778    False
# 779    False
# 780    False
# 781    False
# Name: Year, Length: 782, dtype: bool

# %%
#df = df[released_by_studio & released_in_2015]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1534     def __nonzero__(self):
# -> 1535         raise ValueError(
#    1536             f"The truth value of a {type(self).__name__} is ambiguous. "
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-6cf94844ca3f> in <module>
# ----> 1 df = df[released_by_studio & released_in_2015]
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      68         other = item_from_zerodim(other)
#      69
# ---> 70         return method(self, other)
#      71
#      72     return new_method
#
# ...

# %%
has_dark_in_title = df.index.str.lower().str().contains("dark")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-97f45247883f> in <module>
# ----> 1 has_dark_in_title = df.index.str.lower().str().contains("dark")
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
#     181             return self._accessor
# --> 182         accessor_obj = self._accessor(obj)
#     183         # Replace the property with the accessor object. Inspired by:
#     184         # https://www.pydanny.com/cached-property.html
#
# ~\anaconda3\lib\site-packages\pandas\core\strings\accessor.py in __init__(self, data)
#     175         from pandas.core.arrays.string_ import StringDtype
#     176
# --> 177         self._inferred_dtype = self._validate(data)
#     178         self._is_categorical = is_categorical_dtype(data.dtype)
# ...
