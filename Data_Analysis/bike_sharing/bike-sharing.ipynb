# %%
# import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
# load hourly data 

hourly_data = pd.read_csv('Bike-Sharing-Dataset/hour.csv')

# %%
hourly_data
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# ...        ...         ...     ...  ..   ...  ..      ...      ...
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0               0           1  0.24  0.2879  0.81     0.0000       3
# ...

# %%
# information about data

print(f"Shape of data: {hourly_data.shape}")
print(f"Number of missing values: {hourly_data.isnull().sum().sum()}")
# Out:
# Shape of data: (17379, 17)
# Number of missing values: 0

# %%
# statistics of data

hourly_data.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %%
hourly_data.describe().T # using T columns and rows are interchanged to rows and columns
# Out:
#               count         mean          std   min        25%        50%  \
# instant     17379.0  8690.000000  5017.029500  1.00  4345.5000  8690.0000
# season      17379.0     2.501640     1.106918  1.00     2.0000     3.0000
# yr          17379.0     0.502561     0.500008  0.00     0.0000     1.0000
# mnth        17379.0     6.537775     3.438776  1.00     4.0000     7.0000
# hr          17379.0    11.546752     6.914405  0.00     6.0000    12.0000
# holiday     17379.0     0.028770     0.167165  0.00     0.0000     0.0000
# weekday     17379.0     3.003683     2.005771  0.00     1.0000     3.0000
# workingday  17379.0     0.682721     0.465431  0.00     0.0000     1.0000
# weathersit  17379.0     1.425283     0.639357  1.00     1.0000     1.0000
# temp        17379.0     0.496987     0.192556  0.02     0.3400     0.5000
# atemp       17379.0     0.475775     0.171850  0.00     0.3333     0.4848
# hum         17379.0     0.627229     0.192930  0.00     0.4800     0.6300
# ...

# %%
hourly_data.columns
# Out:
# Index(['instant', 'dteday', 'season', 'yr', 'mnth', 'hr', 'holiday', 'weekday',
#        'workingday', 'weathersit', 'temp', 'atemp', 'hum', 'windspeed',
#        'casual', 'registered', 'cnt'],
#       dtype='object')

# %% [markdown]
# *temporal features*: This contains information about the time at which the record was registered. This group contains the dteday, season, yr, mnth, hr, holiday, weekday, and workingday columns.
#
#
# *weather related features*: This contains information about the weather conditions. The weathersit, temp, atemp, hum, and windspeed columns are included in this group.
#
#
# *record related features*: This contains information about the number of records for the specific hour and date. This group includes the casual, registered, and cnt columns

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Preprocessing Temporal and Weather Features

# %% [markdown]
# The seasons column contains values from 1 to 4, which encode, respectively, the Winter, Spring, Summer, and Fall seasons.
#
# The yr column contains the values 0 and 1 representing 2011 and 2012,
#
# weekday column contains values from 0 to 6, with each one representing a day of the week (0: Sunday, 1: Monday, through to 6: Saturday)
#
# scale the hum column to values between 0 and 100 (as it represents the humidity percentage)
#
# the windspeed column to values between 0 and 67 (as those are the registered minimum and maximum wind speed):

# %%
#1. creating copy of dataset to avoid any misahps affecting our original dataset

preprocessed_data = hourly_data.copy()

# %%
preprocessed_data
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01       1   0     1   0        0        6
# 1            2  2011-01-01       1   0     1   1        0        6
# 2            3  2011-01-01       1   0     1   2        0        6
# 3            4  2011-01-01       1   0     1   3        0        6
# 4            5  2011-01-01       1   0     1   4        0        6
# ...        ...         ...     ...  ..   ...  ..      ...      ...
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0               0           1  0.24  0.2879  0.81     0.0000       3
# ...

# %%
#2. Map the season variable from 1 to 4 to encode with values : which encode, respectively, the Winter, Spring, Summer, and Fall seasons

# %%
# so create dictionary and then use 'apply' and 'lambda' functions

# %%
seasons_mapping = {1:'winter',2:'spring',3:'summer', 4:'fall'}

# %%
seasons_mapping
# Out:
# {1: 'winter', 2: 'spring', 3: 'summer', 4: 'fall'}

# %%
# now applying map and lambda functions to seasons_mapping 

preprocessed_data['season'] = preprocessed_data['season'].apply(lambda x: seasons_mapping[x])

# %%
preprocessed_data # see below output in place of 1 it shows winter
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01  winter   0     1   0        0        6
# 1            2  2011-01-01  winter   0     1   1        0        6
# 2            3  2011-01-01  winter   0     1   2        0        6
# 3            4  2011-01-01  winter   0     1   3        0        6
# 4            5  2011-01-01  winter   0     1   4        0        6
# ...        ...         ...     ...  ..   ...  ..      ...      ...
# 17374    17375  2012-12-31  winter   1    12  19        0        1
# 17375    17376  2012-12-31  winter   1    12  20        0        1
# 17376    17377  2012-12-31  winter   1    12  21        0        1
# 17377    17378  2012-12-31  winter   1    12  22        0        1
# 17378    17379  2012-12-31  winter   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0               0           1  0.24  0.2879  0.81     0.0000       3
# ...

# %%
# now creating dictionary for yera column 

year_mapping = {0: 2011, 1: 2012}

# %%
preprocessed_data['yr'] = preprocessed_data['yr'].apply(lambda x: year_mapping[x])

# %%
preprocessed_data
# Out:
#        instant      dteday  season    yr  mnth  hr  holiday  weekday  \
# 0            1  2011-01-01  winter  2011     1   0        0        6
# 1            2  2011-01-01  winter  2011     1   1        0        6
# 2            3  2011-01-01  winter  2011     1   2        0        6
# 3            4  2011-01-01  winter  2011     1   3        0        6
# 4            5  2011-01-01  winter  2011     1   4        0        6
# ...        ...         ...     ...   ...   ...  ..      ...      ...
# 17374    17375  2012-12-31  winter  2012    12  19        0        1
# 17375    17376  2012-12-31  winter  2012    12  20        0        1
# 17376    17377  2012-12-31  winter  2012    12  21        0        1
# 17377    17378  2012-12-31  winter  2012    12  22        0        1
# 17378    17379  2012-12-31  winter  2012    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# ...

# %%
# now creating dictionary for weekday column 

weekday_mapping = {0:'Sunday',1: 'Monday', 2: 'Tuesday',3: 'Wednesday', 4: 'Thursday', 5: 'Friday',6: 'Saturday'}

# %%
preprocessed_data['weekday'] = preprocessed_data['weekday'].apply(lambda x: weekday_mapping[x])

# %%
preprocessed_data
# Out:
#        instant      dteday  season    yr  mnth  hr  holiday   weekday  \
# 0            1  2011-01-01  winter  2011     1   0        0  Saturday
# 1            2  2011-01-01  winter  2011     1   1        0  Saturday
# 2            3  2011-01-01  winter  2011     1   2        0  Saturday
# 3            4  2011-01-01  winter  2011     1   3        0  Saturday
# 4            5  2011-01-01  winter  2011     1   4        0  Saturday
# ...        ...         ...     ...   ...   ...  ..      ...       ...
# 17374    17375  2012-12-31  winter  2012    12  19        0    Monday
# 17375    17376  2012-12-31  winter  2012    12  20        0    Monday
# 17376    17377  2012-12-31  winter  2012    12  21        0    Monday
# 17377    17378  2012-12-31  winter  2012    12  22        0    Monday
# 17378    17379  2012-12-31  winter  2012    12  23        0    Monday
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# ...

# %% [markdown]
# ###  encoding the weather related columns

# %%
# weathersit , hum(humidity) and windspeed columns

# %% [markdown]
# weathersit column represents the current weather conditions, where 1 stands for clear weather with a few clouds, 2 represents cloudy weather, 3 relates to light snow or rain, and 4 stands for heavy snow or rain
#
# The hum column stands for the current normalized air humidity, with values from 0 to 1 (hence, we will multiply the values of this column by 100, in order to obtain percentages).
#
# windspeed column represents the windspeed, which is again normalized to values between 0 and 67 m/s.

# %%
# transform weathersit column

weather_mapping = {1: 'clear', 2: 'cloudy',3: 'light_rain_snow', 4: 'heavy_rain_snow'}

# %%
preprocessed_data['weathersit'] = preprocessed_data['weathersit'].apply(lambda x: weather_mapping[x])

# %%
preprocessed_data
# Out:
#        instant      dteday  season    yr  mnth  hr  holiday   weekday  \
# 0            1  2011-01-01  winter  2011     1   0        0  Saturday
# 1            2  2011-01-01  winter  2011     1   1        0  Saturday
# 2            3  2011-01-01  winter  2011     1   2        0  Saturday
# 3            4  2011-01-01  winter  2011     1   3        0  Saturday
# 4            5  2011-01-01  winter  2011     1   4        0  Saturday
# ...        ...         ...     ...   ...   ...  ..      ...       ...
# 17374    17375  2012-12-31  winter  2012    12  19        0    Monday
# 17375    17376  2012-12-31  winter  2012    12  20        0    Monday
# 17376    17377  2012-12-31  winter  2012    12  21        0    Monday
# 17377    17378  2012-12-31  winter  2012    12  22        0    Monday
# 17378    17379  2012-12-31  winter  2012    12  23        0    Monday
#
#        workingday weathersit  temp   atemp   hum  windspeed  casual  \
# ...

# %%
# rescale the hum and windspeed columns

preprocessed_data['hum'] = preprocessed_data['hum'] * 100
preprocessed_data['windspeed'] = preprocessed_data['windspeed'] * 67 # 67 bcoz max windspeed occured was 67

# %%
preprocessed_data
# Out:
#        instant      dteday  season    yr  mnth  hr  holiday   weekday  \
# 0            1  2011-01-01  winter  2011     1   0        0  Saturday
# 1            2  2011-01-01  winter  2011     1   1        0  Saturday
# 2            3  2011-01-01  winter  2011     1   2        0  Saturday
# 3            4  2011-01-01  winter  2011     1   3        0  Saturday
# 4            5  2011-01-01  winter  2011     1   4        0  Saturday
# ...        ...         ...     ...   ...   ...  ..      ...       ...
# 17374    17375  2012-12-31  winter  2012    12  19        0    Monday
# 17375    17376  2012-12-31  winter  2012    12  20        0    Monday
# 17376    17377  2012-12-31  winter  2012    12  21        0    Monday
# 17377    17378  2012-12-31  winter  2012    12  22        0    Monday
# 17378    17379  2012-12-31  winter  2012    12  23        0    Monday
#
#        workingday weathersit  temp   atemp   hum  windspeed  casual  \
# ...

# %%
# to view only these columns which were transformed 
# use sample()

cols = ['season', 'yr', 'weekday','weathersit', 'hum', 'windspeed']
preprocessed_data[cols].sample(20,random_state=42)
# Out:
#        season    yr    weekday weathersit   hum  windspeed
# 12830  summer  2012   Saturday      clear  27.0    12.9980
# 8688   winter  2012     Monday      clear  41.0    15.0013
# 7091     fall  2011     Friday      clear  66.0    19.0012
# 12230  spring  2012    Tuesday      clear  52.0    23.9994
# 431    winter  2011   Thursday      clear  56.0    26.0027
# 1086   winter  2011     Friday      clear  72.0    19.0012
# 11605  spring  2012   Thursday      clear  58.0     8.9981
# 7983     fall  2011     Sunday      clear  87.0     0.0000
# 10391  winter  2012  Wednesday      clear  68.0    12.9980
# 7046     fall  2011  Wednesday      clear  71.0    15.0013
# 17355  winter  2012     Monday      clear  55.0    12.9980
# 11369  spring  2012     Monday      clear  76.0    12.9980
# 12659  spring  2012   Saturday     cloudy  37.0     7.0015
# 12695  spring  2012     Monday     cloudy  77.0    12.9980
# 6147   summer  2011     Sunday     cloudy  64.0    12.9980
# ...

# %% [markdown]
# #### Users who registerd(Registered) and users who did not (casual)

# %%
# the number of rides performed by registered users versus the number of rides performed by non-registered (or casual) ones.
# These numbers are represented in the registered and casual columns, respectively, 
# with the cnt column representing the sum of the registered and casual rides.

# %%
# now how to know that registered + casual = cnt ?
# to verify this use 'assert'

assert (preprocessed_data.casual + preprocessed_data.registered == preprocessed_data.cnt).all(),'Sum of casual and registered rides not equal to total number of rides'

# %%
# visualising registered and casual distribution

sns.distplot(preprocessed_data['registered'], label = 'registered users')
sns.distplot(preprocessed_data['casual'], label = 'casual users')

plt.legend()
plt.xlabel('rides')
plt.title("distribution- 01")
plt.savefig('figs/distribution- 01.png' , format ='png')
# Out:
# C:\Users\Manjunath\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Manjunath\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# evolution of rides over time. We can analyze the number of rides each day

plot_data = preprocessed_data[['registered','casual','dteday']]

ax = plot_data.groupby('dteday').sum().plot(figsize=(12,6))

ax.set_xlabel("time")
ax.set_ylabel("number of rides per day")
plt.savefig('figs/rides_daily.png', format='png')


# we first take a subset of the original preprocessed_data dataset. Afterward, we compute the total number of rides for each day
# by first grouping the data by the dteday column,
# and then summing the single entries for the casual and registered columns.

# %% [markdown]
# #### distributions of the requests over separate hours and days of the week.

# %%
# selecting the columns in focus

plot_data = preprocessed_data[['hr','weekday','registered','casual']]


#  the melt() function, applied on a pandas dataset. It will create a new dataset,
# in which values are grouped by the hr and weekday columns,
# while creating two new columns: type (containing the casual and registered values) 
# and count (containing the respective counts for the casual and registered types).

plot_data = plot_data.melt(id_vars=['hr','weekday'] , var_name='type' , value_name='count')


# create FacetGrid object, in which a grid plot is produced.
# As columns, we have the various days of the week,
#as rows, the different types (registered and casual)

# seaborn.FacetGrid() function will create a new grid of plots, with 
# rows corresponding to the different days of the week and columns corresponding to the types

grid = sns.FacetGrid(plot_data, row='weekday', col='type', height=3, aspect=3 , row_order=['Monday', 'Tuesday', 'Wednesday', 'Thursday','Friday', 'Saturday', 'Sunday'])


# the map() function is applied to each element of the grid, creating the respective plots

grid.map(sns.barplot, 'hr', 'count' , alpha=0.5)

grid.savefig('figs/weekday_hour_distributions.png', format='png')
# Out:
# C:\Users\Manjunath\anaconda3\lib\site-packages\seaborn\axisgrid.py:643: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# ### Analyzing Seasonal Impact on Rides

# %%
# create grid plots, similar to above in which the 
# number of rides will be distributed over hours and weekdays, based on the current season.

# %%
# distribution based on hour(hr) and season
plot_data = preprocessed_data[['hr','season','registered','casual']] # instead of weekday  we now want season

plot_data = plot_data.melt(id_vars=['hr','season'] , var_name='type' , value_name='count')

grid = sns.FacetGrid(plot_data, row='season',col='type', height=2.5,aspect=2.5,row_order=['winter', 'spring','summer', 'fall'])

grid.map(sns.barplot, 'hr', 'count' , alpha=0.5)

grid.savefig('figs/season_hour_distributions.png', format='png')
# Out:
# C:\Users\Manjunath\anaconda3\lib\site-packages\seaborn\axisgrid.py:643: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
# now distribution based on weekdays and season

plot_data = preprocessed_data[['weekday','season','registered','casual']] # instead of weekday  we now want season

plot_data = plot_data.melt(id_vars=['weekday','season'] , var_name='type' , value_name='count')

grid = sns.FacetGrid(plot_data, row='season',col='type', height=2.5,aspect=2.5,row_order=['winter', 'spring','summer', 'fall'])

grid.map(sns.barplot, 'weekday', 'count' , alpha=0.5)

grid.savefig('figs/season_weekday_distributions.png', format='png')
# Out:
# C:\Users\Manjunath\anaconda3\lib\site-packages\seaborn\axisgrid.py:643: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %% [markdown]
# ### the following probability distributions will be used: Student's t-distribution (for t-tests); Standard normal or z-distribution (for z-tests); Chi-squared distribution (for a chi-squared test) and F-distribution (for F-tests).

# %% [markdown]
# Choosing which distribution to use depends on the sample size and the type of test.
#
# **As a rule of thumb, if the sample size is greater than 30, we can expect that the assumptions of the central limit theorem hold and that the test statistic follows a normal distribution (hence, use a z-test)**

# %% [markdown]
# **for samples with less than 30 entries, a t-test should be used (with a test statistic following Student's t-distribution).**

# %% [markdown]
# ### Steps involved while applying statistics
#
# **Steps in statistics:**
#
# 1. Identifying the appropriate test statistic
#
# 2. Specifying the significance level:
#
# 3. Two-sided tests
#
# 4. One-sided tests

# %% [markdown]
# **The p-value is the smallest level of significance at which the null hypothesis can be rejected. The p-value also provides the probability of obtaining the observed sample statistic, assuming that the null hypothesis is correct**
#
#
# **f the obtained p-value is less than the specified significance level, we can reject the null hypothesis, hence the p-value approach is, in practice, an alternative (and, most of the time, a more convenient) way to perform hypothesis testing.**

# %% [markdown]
# ### Estimating Average Registered Rides
#
# Performing hypothesis testing  on dataset

# %%
#1 . Get the null (null hypothesis) by computing average number of registered rides per hour
# compute the population statistics

population_mean = preprocessed_data.registered.mean()


# now get the sample of data from the population

sample = preprocessed_data[(preprocessed_data.season == 'summer') & (preprocessed_data.yr == 2011)].registered


# now specify the significance level i.e the p-value
# standard value = 0.05 which is 5%
# if the p-value obtained by the statistical test is less than 0.05, you can reject the null hypothesis by at least 95%


# performing t-test and compute the p-value for the same

from scipy.stats import ttest_1samp
test_result = ttest_1samp(sample,population_mean)

print(f"Test statistic: {test_result[0]}, p-value: {test_result[1]}")
# Out:
# Test statistic: -3.491969148378619, p-value: 0.0004887645279519517

# %% [markdown]
# So p-value is =  0.0004887645279519517 which is smaller than 0.01 (i.e 0.05)
# therefore we can reject null hypothesis and asssume that alternative hypothesis is correct!
#
# But this is a biased result as I took only summer season and year 2011 but not the complete datasset!

# %%
# now performing same test on whole 5% of dataset 

import random
random.seed(42)
sample_unbiased = preprocessed_data.registered.sample(frac=0.05) # 5% of sampel data
test_result_unbiased = ttest_1samp(sample_unbiased,population_mean)
print(f"Test statistic: {test_result_unbiased[0]}, p-value: {test_result_unbiased[1]}")
# Out:
# Test statistic: 0.45024419331010834, p-value: 0.6526468027927973

# %% [markdown]
# **Now p value is 0.65!! which is higher than 0.05**
#
# so null hypothesis cannot be rejected

# %% [markdown]
# #### Some more tests

# %%
#1. We saw graphically, that registered users tend to perform more rides during working days than the weekend. 
# we will test whether the mean of registered rides during working days is the same as during the weekend.

# %%
# Hypothesis Testing on Registered Rides

# %% [markdown]
# identifying whether there is a statistically significant difference between registered rides during working days and the weekend. Therefore, our null hypothesis is that the average number of rides for registered users during working days is the same as the average number of rides during the weekend.

# %% [markdown]
# H_0 : (average registered rides over weekdays) - (average registered rides over weekend) = 0
#
# and
#
# H_a : (average registered rides over weekdays) - (average registered rides over weekend) ≠ 0

# %%
# after establishing null hypothesis collect the data

weekend_days = ['Saturday','Sunday']
weekend_mask = preprocessed_data.weekday.isin(weekend_days)

workingdays_mask = ~preprocessed_data.weekday.isin(weekend_days)

# select registered rides for the weekend and working days

weekend_data = preprocessed_data.registered[weekend_mask]
workingdays_data = preprocessed_data.registered[workingdays_mask]

# %%
# performn two-sample t tests

from scipy.stats import ttest_ind
test_res = ttest_ind(weekend_data,workingdays_data)

print(f"Statistic value: {test_res[0]:.08f},p-value: {test_res[1]:.08f}")
# Out:
# Statistic value: -16.00363492,p-value: 0.00000000

# %% [markdown]
# resulting p value is smaller than 0.01 which is below than 0.05
# we can reject the null hypothesis and confirm that our initial observation is correct: that is, there is a statistically significant difference between the number of rides performed during working days and the weekend.

# %%
# plotting distribution
# of registered rides for working vs weekend days

sns.distplot(weekend_data, label='weekend days')

sns.distplot(workingdays_data, label='working days')

plt.legend()

plt.xlabel('rides')

plt.ylabel('frequency')

plt.title("Registered rides distributions")

plt.savefig('figs/registered rides for working vs weekend days.png', format='png')
# Out:
# C:\Users\Manjunath\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Manjunath\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# now performing same test for testing casual users perform more rides during the weekend.
#
# null hypothesis = the null hypothesis is that the average number of rides during working days is the same as the average number of rides during the weekend,
#
# so , The alternative hypothesis will then result in a statistically significant difference in the average number of rides between the two groups:

# %%
# casual rides for weekday and weekend

weekend_data = preprocessed_data.casual[weekend_mask]
workingdays_data = preprocessed_data.casual[workingdays_mask]

# performing ttest

test_res = ttest_ind(weekend_data,workingdays_data)

print(f"Statistic value: {test_res[0]:.03f}, p-value: {test_res[1]:.03f}")
# Out:
# Statistic value: 41.077, p-value: 0.000

# %%
# plot distributions of casual rides for working vs weekend days

sns.distplot(weekend_data, label='weekend days')

sns.distplot(workingdays_data, label='working days')

plt.legend()

plt.xlabel('rides')

plt.ylabel('frequency')

plt.title("Casual rides distributions")

plt.savefig('figs/casual rides for working vs weekend days.png', format='png')
# Out:
# C:\Users\Manjunath\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Manjunath\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### In conclusion, we can say that there is a statistically significant difference between the number of rides on working days and weekend days for both casual and registered customers.

# %% [markdown]
# ### Now perfroming for weather related features!

# %% [markdown]
# casual and regsitered variables are continuously distributed and also weather related features are also continuously distributed
# so we use correlation to measure the relationship between two different continuous variables.

# %%
# we have multiple variables so writing for each variable is lengthy
# so make one function and apply that to other varaibles

def plot_correlations(data,col):
    # correlation between col and registered rides
    corr_r = np.corrcoef(data[col], data["registered"])[0,1]
    ax = sns.regplot(x=col, y="registered" , data =data , scatter_kws={"alpha": 0.05}, label = f"Registered rides(correlation:{corr_r:.3f})")
    
     # correlation between col and casual rides
    corr_c = np.corrcoef(data[col], data["casual"])[0,1]   
    ax = sns.regplot(x=col, y="casual" , data =data , scatter_kws={"alpha": 0.05}, label = f"Casual rides(correlation:{corr_c:.3f})")
    
    # adjusting sns parameters
    
    legend = ax.legend()
    
    for lh in legend.legendHandles:
        lh.set_alpha(0.5)
    ax.set_ylabel("rides")
    ax.set_title(f"Correlation between rides and {col}")
    
    return ax

# %%
# now applying this function on our variables : temp, atemp, hum, and windspeed

# %%
plt.figure(figsize=(12,8))

ax = plot_correlations(preprocessed_data, 'temp')

plt.savefig('figs/correlation_temp.png', format='png')

# %%
plt.figure(figsize=(12,8))

ax = plot_correlations(preprocessed_data, 'atemp')

plt.savefig('figs/correlation_atemp.png', format='png')

# %%
plt.figure(figsize=(10,8))
ax = plot_correlations(preprocessed_data, 'hum')
plt.savefig('figs/correlation_hum.png', format='png')

plt.figure(figsize=(10,8))
ax = plot_correlations(preprocessed_data, 'windspeed')
plt.savefig('figs/correlation_windspeed.png', format='png')

# %% [markdown]
# the humidity level has a negative correlation with both types of rides (-0.274 for registered and -0.347 for casual). This means that with a high level of humidity (mist or rain), customers will tend not to use the bike sharing service.

# %% [markdown]
# ### Evaluating the Difference between the Pearson and Spearman Correlations
#
# bcoz pearson correlation assumes a linear relationship with random variables (which is often not the case)

# %%
# for spearman rank correlation 

# define random variables

x = np.linspace(0,5, 100)

y_lin = 0.5*x + 0.1*np.random.randn(100)

y_mon = np.exp(x) + 0.1*np.random.randn(100)

# %%
#Compute the Pearson and Spearman correlations using the pearsonr() and spearmanr() functions in the scipy.stats module:

# %%
from scipy.stats import pearsonr,spearmanr
corr_lin_pearson = pearsonr(x,y_lin)[0]
corr_lin_spearman = spearmanr(x,y_lin)[0]

corr_mon_pearson = pearsonr(x, y_mon)[0]
corr_mon_spearman = spearmanr(x, y_mon)[0]

# %% [markdown]
# both the pearsonr() and spearmanr() functions return a two-dimensional array in which the first value is the respective correlation, while the second one is the p-value of a hypothesis test in which the null hypothesis assumes that the computed correlation is equal to zero

# %%
# visualizing the data and correlations

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10,5))
ax1.scatter(x, y_lin)
ax1.set_title(f"Linear relationship\n Pearson: {corr_lin_pearson:.3f}, Spearman: {corr_lin_spearman:.3f}")
ax2.scatter(x, y_mon)
ax2.set_title(f"Monotonic relationship\n Pearson: {corr_mon_pearson:.3f}, Spearman: {corr_mon_spearman:.3f}")
fig.savefig('figs/pearson VS spearman.png', format='png')

# %% [markdown]
# **spearman correlation = 1 which means that it has perfectly captured the relationship between 2 variables (better than pearson!)**

# %%
# define function for computing correlations
def compute_correlations(data, col):
    pearson_reg = pearsonr(data[col], data["registered"])[0]
    pearson_cas = pearsonr(data[col], data["casual"])[0]
    spearman_reg = spearmanr(data[col], data["registered"])[0]
    spearman_cas = spearmanr(data[col], data["casual"])[0]

    return pd.Series({"Pearson (registered)": pearson_reg, 
                      "Spearman (registered)": spearman_reg,
                      "Pearson (casual)": pearson_cas, 
                      "Spearman (casual)": spearman_cas})

# compute correlation measures between different features
cols = ["temp", "atemp", "hum", "windspeed"]
corr_data = pd.DataFrame(index=["Pearson (registered)", "Spearman (registered)", "Pearson (casual)", "Spearman (casual)"])

for col in cols:
    corr_data[col] =  compute_correlations(preprocessed_data, col)
    
corr_data.T
# Out:
#            Pearson (registered)  Spearman (registered)  Pearson (casual)  \
# temp                   0.335361               0.373196          0.459616
# atemp                  0.332559               0.373014          0.454080
# hum                   -0.273933              -0.338480         -0.347028
# windspeed              0.082321               0.122936          0.090287
#
#            Spearman (casual)
# temp                0.570989
# atemp               0.570419
# hum                -0.388213
# windspeed           0.122920

# %% [markdown]
# difference between the two coefficients occurs when comparing the temp (and atemp) and casual columns. More precisely, the Spearman correlation is quite high, meaning that there is significant evidence for a nonlinear, relatively strong and positive relationship

# %% [markdown]
# **An interpretation of this result is that casual customers are far keener on using the bike sharing service when temperatures are higher. We have already seen from our previous analysis that casual customers ride mostly during the weekend, and they do not rely on bike sharing services for commuting to work. This conclusion is again confirmed by the strong relationship with temperature, as opposed to registered customers, whose rides have a weaker correlation with temperature.**
